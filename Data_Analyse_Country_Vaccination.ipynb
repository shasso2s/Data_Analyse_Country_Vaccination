# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('datasets/country_vaccinations.csv')
data
# Out:
#        country iso_code        date  total_vaccinations  people_vaccinated  \
# 0      Albania      ALB  2021-01-10                 0.0                0.0
# 1      Albania      ALB  2021-01-11                 NaN                NaN
# 2      Albania      ALB  2021-01-12               128.0              128.0
# 3      Albania      ALB  2021-01-13               188.0              188.0
# 4      Albania      ALB  2021-01-14               266.0              266.0
# ...        ...      ...         ...                 ...                ...
# 6103  Zimbabwe      ZWE  2021-03-08             35518.0            35518.0
# 6104  Zimbabwe      ZWE  2021-03-09             35761.0            35761.0
# 6105  Zimbabwe      ZWE  2021-03-10             35901.0            35901.0
# 6106  Zimbabwe      ZWE  2021-03-11             36019.0            36019.0
# 6107  Zimbabwe      ZWE  2021-03-12             36283.0            36283.0
#
# ...

# %%
data.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        3.908000e+03       3.481000e+03             2.368000e+03
# mean         2.137405e+06       1.757376e+06             6.805378e+05
# std          7.429941e+06       5.602469e+06             2.731855e+06
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          3.543250e+04       3.363300e+04             1.603475e+04
# 50%          2.386460e+05       2.220050e+05             8.489250e+04
# 75%          1.112548e+06       9.113120e+05             4.257090e+05
# max          1.011280e+08       6.596530e+07             3.500016e+07
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            3.298000e+03        5.917000e+03
# mean             8.291843e+04        5.791961e+04
# std              2.431662e+05        1.893580e+05
# min              0.000000e+00        1.000000e+00
# 25%              2.618000e+03        1.122000e+03
# ...

# %%
data.isna().sum()# sum dyal nan value
# Out:
# country                                   0
# iso_code                                356
# date                                      0
# total_vaccinations                     2200
# people_vaccinated                      2627
# people_fully_vaccinated                3740
# daily_vaccinations_raw                 2810
# daily_vaccinations                      191
# total_vaccinations_per_hundred         2200
# people_vaccinated_per_hundred          2627
# people_fully_vaccinated_per_hundred    3740
# daily_vaccinations_per_million          191
# vaccines                                  0
# source_name                               0
# source_website                            0
# dtype: int64

# %%
#fill nan value to 0
data=data.replace([np.inf,-np.inf],np.nan)# np.inf,-np.inf wird durch np.nan ersetzt
data=data.fillna(0)# nan value wird duch 0 ersetzt
data.isna().sum()# zeigt wie viel nan haben wir und zwar für jede feature
# Out:
# country                                0
# iso_code                               0
# date                                   0
# total_vaccinations                     0
# people_vaccinated                      0
# people_fully_vaccinated                0
# daily_vaccinations_raw                 0
# daily_vaccinations                     0
# total_vaccinations_per_hundred         0
# people_vaccinated_per_hundred          0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations_per_million         0
# vaccines                               0
# source_name                            0
# source_website                         0
# dtype: int64

# %%
data.head(1)
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      0.0                     0.0                 0.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  0.0                             0.0
#
#           vaccines         source_name  \
# 0  Pfizer/BioNTech  Ministry of Health
#
#                                       source_website
# 0  https://shendetesia.gov.al/covid19-ministria-e...

# %%
data.vaccines.value_counts()
# Out:
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                          1549
# Pfizer/BioNTech                                                                       1149
# Oxford/AstraZeneca, Pfizer/BioNTech                                                    871
# Oxford/AstraZeneca                                                                     447
# Moderna, Pfizer/BioNTech                                                               371
# Sputnik V                                                                              203
# Sinovac                                                                                197
# Pfizer/BioNTech, Sinovac                                                               146
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                      144
# Sinopharm/Beijing                                                                      110
# ...

# %%
data.head(1)
# Out:
#    country iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Albania      ALB  2021-01-10                 0.0                0.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      0.0                     0.0                 0.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                  0.0                             0.0
#
#           vaccines         source_name  \
# 0  Pfizer/BioNTech  Ministry of Health
#
#                                       source_website
# 0  https://shendetesia.gov.al/covid19-ministria-e...

# %%
# sortierung nach high total vaccination
data.sort_values(by='total_vaccinations',ascending=False).head(10).style.background_gradient(cmap="CMRmap_r")
# Out:
# <style  type="text/css" >
#     #T_8c60cba1_84b7_11eb_972b_0cdd24405ef6row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8c60cba1_84b7_11eb_972b_0cdd24405ef6row0_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8c60cba1_84b7_11eb_972b_0cdd24405ef6row0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8c60cba1_84b7_11eb_972b_0cdd24405ef6row0_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8c60cba1_84b7_11eb_972b_0cdd24405ef6row0_col7 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8c60cba1_84b7_11eb_972b_0cdd24405ef6row0_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_8c60cba1_84b7_11eb_972b_0cdd24405ef6row0_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
# ...

# %%
#extraire Oxford/AstraZeneca, Sinopharm/Beijing und sortieren sie diese herausgenommene Daten nach total vaccination
data[data['vaccines']=='Oxford/AstraZeneca, Sinopharm/Beijing'].sort_values(by='total_vaccinations',ascending=False).head(10).style.background_gradient(cmap="CMRmap_r")
# Out:
# <style  type="text/css" >
#     #T_5161fa08_84b9_11eb_8d6e_0cdd24405ef6row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_5161fa08_84b9_11eb_8d6e_0cdd24405ef6row0_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_5161fa08_84b9_11eb_8d6e_0cdd24405ef6row0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_5161fa08_84b9_11eb_8d6e_0cdd24405ef6row0_col6 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_5161fa08_84b9_11eb_8d6e_0cdd24405ef6row0_col7 {
#             background-color:  #f8511c;
#             color:  #000000;
#         }    #T_5161fa08_84b9_11eb_8d6e_0cdd24405ef6row0_col8 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_5161fa08_84b9_11eb_8d6e_0cdd24405ef6row0_col9 {
#             background-color:  #000000;
#             color:  #f1f1f1;
# ...

# %%
data[data["vaccines"]=="Pfizer/BioNTech"].sort_values(by='total_vaccinations',ascending=False).head(10).style.background_gradient(cmap="CMRmap_r")
# Out:
# <style  type="text/css" >
#     #T_0fc8bb28_84bf_11eb_9575_0cdd24405ef6row0_col3 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0fc8bb28_84bf_11eb_9575_0cdd24405ef6row0_col4 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0fc8bb28_84bf_11eb_9575_0cdd24405ef6row0_col5 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_0fc8bb28_84bf_11eb_9575_0cdd24405ef6row0_col6 {
#             background-color:  #242478;
#             color:  #f1f1f1;
#         }    #T_0fc8bb28_84bf_11eb_9575_0cdd24405ef6row0_col7 {
#             background-color:  #e68101;
#             color:  #000000;
#         }    #T_0fc8bb28_84bf_11eb_9575_0cdd24405ef6row0_col8 {
#             background-color:  #a13479;
#             color:  #f1f1f1;
#         }    #T_0fc8bb28_84bf_11eb_9575_0cdd24405ef6row0_col9 {
#             background-color:  #903287;
#             color:  #f1f1f1;
# ...

# %%
# display united kindgdom vaccination details, date, totla_vaccinations , vaccines
display(data[data["country"]=="United Kingdom"] [["date","total_vaccinations","vaccines"]].sort_values(by="total_vaccinations",ascending=False).style.background_gradient(cmap="CMRmap_r"))
# Out:
# <style  type="text/css" >
#     #T_225ee589_84bf_11eb_8f38_0cdd24405ef6row0_col1 {
#             background-color:  #000000;
#             color:  #f1f1f1;
#         }    #T_225ee589_84bf_11eb_8f38_0cdd24405ef6row1_col1 {
#             background-color:  #04040c;
#             color:  #f1f1f1;
#         }    #T_225ee589_84bf_11eb_8f38_0cdd24405ef6row2_col1 {
#             background-color:  #08081c;
#             color:  #f1f1f1;
#         }    #T_225ee589_84bf_11eb_8f38_0cdd24405ef6row3_col1 {
#             background-color:  #0c0c28;
#             color:  #f1f1f1;
#         }    #T_225ee589_84bf_11eb_8f38_0cdd24405ef6row4_col1 {
#             background-color:  #0e0e30;
#             color:  #f1f1f1;
#         }    #T_225ee589_84bf_11eb_8f38_0cdd24405ef6row5_col1 {
#             background-color:  #111138;
#             color:  #f1f1f1;
#         }    #T_225ee589_84bf_11eb_8f38_0cdd24405ef6row6_col1 {
#             background-color:  #17174c;
#             color:  #f1f1f1;
# ...

# %%
data.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %%
data.drop(["source_website","source_name","daily_vaccinations_per_million"],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'vaccines'],
#       dtype='object')

# %%
# In Morocco top 19 days Graph
df1=pd.DataFrame()
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1[["country","date","total_vaccinations","people_vaccinated","people_fully_vaccinaed"]]=data[["country","date","total_vaccinations","people_vaccinated","people_fully_vaccinated"]]

# %%
df1
# Out:
#         county        date  total_vaccinations  people_vaccinated  \
# 0      Albania  2021-01-10                 0.0                0.0
# 1      Albania  2021-01-11                 0.0                0.0
# 2      Albania  2021-01-12               128.0              128.0
# 3      Albania  2021-01-13               188.0              188.0
# 4      Albania  2021-01-14               266.0              266.0
# ...        ...         ...                 ...                ...
# 6103  Zimbabwe  2021-03-08             35518.0            35518.0
# 6104  Zimbabwe  2021-03-09             35761.0            35761.0
# 6105  Zimbabwe  2021-03-10             35901.0            35901.0
# 6106  Zimbabwe  2021-03-11             36019.0            36019.0
# 6107  Zimbabwe  2021-03-12             36283.0            36283.0
#
#       people_fully_vaccinaed   country
# 0                        0.0   Albania
# 1                        0.0   Albania
# 2                        0.0   Albania
# ...

# %%
Marocco=df1[df1["country"]=="Morocco"].sort_values(by="total_vaccinations",ascending=False).head(10)
Marocco
# Out:
#        county        date  total_vaccinations  people_vaccinated  \
# 3897  Morocco  2021-03-12           5394092.0          4169133.0
# 3896  Morocco  2021-03-11           5102685.0          4130606.0
# 3895  Morocco  2021-03-10           4934283.0          4080009.0
# 3894  Morocco  2021-03-09           4734200.0          4017087.0
# 3893  Morocco  2021-03-08           4613292.0          3961941.0
# 3891  Morocco  2021-03-06           4492557.0          3913615.0
# 3890  Morocco  2021-03-05           4377629.0          3877687.0
# 3889  Morocco  2021-03-04           4233129.0          3820097.0
# 3888  Morocco  2021-03-03           4105862.0          3745173.0
# 3887  Morocco  2021-03-02           3951325.0          3657468.0
#
#       people_fully_vaccinaed  country
# 3897               1224959.0  Morocco
# 3896                972079.0  Morocco
# 3895                854274.0  Morocco
# 3894                717113.0  Morocco
# 3893                651351.0  Morocco
# ...

# %%
Morocco=Marocco.sort_values(by="date")
Morocco
# Out:
#        county        date  total_vaccinations  people_vaccinated  \
# 3887  Morocco  2021-03-02           3951325.0          3657468.0
# 3888  Morocco  2021-03-03           4105862.0          3745173.0
# 3889  Morocco  2021-03-04           4233129.0          3820097.0
# 3890  Morocco  2021-03-05           4377629.0          3877687.0
# 3891  Morocco  2021-03-06           4492557.0          3913615.0
# 3893  Morocco  2021-03-08           4613292.0          3961941.0
# 3894  Morocco  2021-03-09           4734200.0          4017087.0
# 3895  Morocco  2021-03-10           4934283.0          4080009.0
# 3896  Morocco  2021-03-11           5102685.0          4130606.0
# 3897  Morocco  2021-03-12           5394092.0          4169133.0
#
#       people_fully_vaccinaed  country
# 3887                293857.0  Morocco
# 3888                360689.0  Morocco
# 3889                413032.0  Morocco
# 3890                499942.0  Morocco
# 3891                578942.0  Morocco
# ...

# %%
plt.xlabel("date")
plt.ylabel("people_vaccined")
plt.title("Morocco country top chart")
plt.plot(Morocco.date.head(),Morocco.people_vaccinated.head(),".--b")
plt.plot(Morocco.date.head(),Morocco.total_vaccinations.head(),".--g")
plt.plot(Morocco.date.head(),Morocco.people_fully_vaccinaed.head(),".--r")
plt.grid()

# %%
data.vaccines.value_counts()
# Out:
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                          1549
# Pfizer/BioNTech                                                                       1149
# Oxford/AstraZeneca, Pfizer/BioNTech                                                    871
# Oxford/AstraZeneca                                                                     447
# Moderna, Pfizer/BioNTech                                                               371
# Sputnik V                                                                              203
# Sinovac                                                                                197
# Pfizer/BioNTech, Sinovac                                                               146
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                      144
# Sinopharm/Beijing                                                                      110
# ...

# %%
print(" Total Population Vaccinated around the world .",data.total_vaccinations.sum())
# Out:
#  Total Population Vaccinated around the world . 8352979291.0

# %%
list(data.country.value_counts().index)
# Out:
# ['England',
#  'Northern Ireland',
#  'United Kingdom',
#  'Wales',
#  'Canada',
#  'Scotland',
#  'Russia',
#  'Israel',
#  'United States',
#  'Bahrain',
#  'Costa Rica',
#  'Mexico',
#  'Chile',
#  'Qatar',
#  'China',
#  'Germany',
#  'Lithuania',
#  'Czechia',
#  'Portugal',
#  'Italy',
#  'Sweden',
#  'Slovenia',
#  'France',
#  'Greece',
#  'Hungary',
#  'Denmark',
#  'Romania',
#  'Norway',
#  'Austria',
#  'Argentina',
#  'Belgium',
#  'Bulgaria',
#  'Estonia',
#  'Poland',
#  'Oman',
#  'Iceland',
#  'Luxembourg',
#  'Finland',
#  'Kuwait',
#  'Latvia',
#  'Cayman Islands',
#  'Croatia',
#  'Ireland',
#  'Slovakia',
#  'Spain',
#  'United Arab Emirates',
#  'Saudi Arabia',
#  'Serbia',
#  'Gibraltar',
#  'Seychelles',
#  'Cyprus',
#  'Albania',
#  'Bermuda',
#  'Indonesia',
#  'Turkey',
#  'India',
#  'Singapore',
#  'Brazil',
#  'Azerbaijan',
#  'Malta',
#  'Panama',
#  'Belarus',
#  'Isle of Man',
#  'Ecuador',
#  'Netherlands',
#  'Switzerland',
#  'Bangladesh',
# ...

# %%
data[data["country"]=="India"]
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 2635   India      IND  2021-01-15                 0.0                0.0
# 2636   India      IND  2021-01-16            191181.0           191181.0
# 2637   India      IND  2021-01-17            224301.0           224301.0
# 2638   India      IND  2021-01-18            454049.0           454049.0
# 2639   India      IND  2021-01-19            674835.0           674835.0
# 2640   India      IND  2021-01-20            806484.0           806484.0
# 2641   India      IND  2021-01-21           1043534.0          1043534.0
# 2642   India      IND  2021-01-22           1390592.0          1390592.0
# 2643   India      IND  2021-01-23           1582201.0          1582201.0
# 2644   India      IND  2021-01-24           1615504.0          1615504.0
# 2645   India      IND  2021-01-25           2023809.0          2023809.0
# 2646   India      IND  2021-01-26           2029480.0          2029480.0
# ...

# %%
print("in india Total vaccinations count is ",data[data["country"]=="India"].total_vaccinations.sum())
# Out:
# in india Total vaccinations count is  520035874.0

# %%
#the top countries with hightest vaccination count
cols=["country","total_vaccinations"]
df10=data[cols].groupby('country').sum().sort_values("total_vaccinations",ascending=False)
df10=df10.head(10)
df10=df10.sort_values(by="total_vaccinations",ascending=True)
df10=df10.reset_index()
df10
# Out:
#                 country  total_vaccinations
# 0                 China        2.110070e+08
# 1                Brazil        2.390667e+08
# 2               Germany        2.482996e+08
# 3  United Arab Emirates        2.662265e+08
# 4                Turkey        2.732764e+08
# 5                Israel        3.814093e+08
# 6                 India        5.200359e+08
# 7               England        7.045414e+08
# 8        United Kingdom        8.293203e+08
# 9         United States        2.867864e+09

# %%
plt.plot(df10.total_vaccinations,df10.country,"*--g")
plt.ylabel("country",fontsize="15")
plt.xlabel("total_vaccinations",fontsize="15")
plt.title("countries with highest vaccination count", fontsize="20")
plt.show()

# %%
plt.barh(df10.country,df10.total_vaccinations)
plt.ylabel("country",fontsize="15")
plt.xlabel("total_vaccinations",fontsize="15")
plt.title("countries with highest vaccination count", fontsize="20")
plt.show()

# %%
cols=["country","total_vaccinations_per_hundred"]
df11=data[cols].groupby('country').sum().sort_values('total_vaccinations_per_hundred',ascending=False)
df11=df11.head(10)
df11=df11.sort_values(by="total_vaccinations_per_hundred",ascending=True)
df11=df11.reset_index()
df11
# Out:
#                 country  total_vaccinations_per_hundred
# 0         United States                          857.50
# 1              Scotland                         1151.13
# 2      Northern Ireland                         1185.43
# 3        United Kingdom                         1221.66
# 4                 Wales                         1242.89
# 5               England                         1251.70
# 6            Seychelles                         1719.57
# 7  United Arab Emirates                         2691.74
# 8             Gibraltar                         4018.57
# 9                Israel                         4406.55

# %%
plt.plot(df11.total_vaccinations_per_hundred,df11.country,"+--g")
plt.xlabel("country")
plt.ylabel("total_vaccinations_per_hundred")
plt.title("countries with hightest vaccination count",fontsize="20")
plt.show()

# %%
plt.barh(df11.country,df11.total_vaccinations_per_hundred)
plt.xlabel("country")
plt.ylabel("total_vaccinations_per_hundred")
plt.title("countries with hightest vaccination count",fontsize="20")
plt.show()
